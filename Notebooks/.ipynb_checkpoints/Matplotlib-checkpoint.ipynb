# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(100, 201)
plt.plot(data)

# %%
f, ax = plt.subplots(2, 1)
ax[0].plot(np.arange(100,150))
ax[1].plot(np.arange(50,75))

# %%
f, ax = plt.subplots(2, 1, sharex=True)
ax[0].plot(np.arange(100,150))
ax[1].plot(np.arange(50,75))

# %%
plt.plot([1, 2, 3], [3, 6, 9], '-r')
plt.plot([1, 2, 3], [2, 4, 9], ':g')

# %%
N = 20

# %%
np.random.rand(N)
# Out:
# array([0.30629193, 0.6270232 , 0.21668964, 0.31141615, 0.75908828,
#        0.60167428, 0.62617226, 0.19312598, 0.09926247, 0.27701765,
#        0.15708978, 0.77435519, 0.92517334, 0.45536677, 0.1806715 ,
#        0.96440925, 0.7825036 , 0.43025802, 0.26992569, 0.5751413 ])

# %%
plt.scatter(np.random.rand(N),
            np.random.rand(N),
            c='r', s=100, alpha=0.5)

plt.scatter(np.random.rand(N),
            np.random.rand(N),
            c='g', s=200, alpha=0.5)

plt.scatter(np.random.rand(N),
            np.random.rand(N),
            c='b', s=300, alpha=0.5)

# %%
data = np.random.rand(7)

# %%
labels = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plt.pie(data, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.legend()

# %%
x = np.arange(7)
y = np.random.randint(low=0, high=100, size=7)
labels = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plt.title("Weekday Data")
plt.bar(x, y, alpha=0.8, color=colors, tick_label=labels)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ### Visualização 3D

# %%
from mpl_toolkits import mplot3d

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 30, cmap='binary')

# %%
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='Spectral_r')
